# %%
import time
import networkx as nx
import numpy as np
from copy import deepcopy
from collections import namedtuple
import torch
import pyro

from spatial_scene_grammars.nodes import *
from spatial_scene_grammars.rules import *
from spatial_scene_grammars.scene_grammar import *
from spatial_scene_grammars.parsing import *

# %%
from spatial_scene_grammars_examples.singles_pairs.grammar_constituency import *
pyro.set_rng_seed(42)

grammar = SpatialSceneGrammar(
    root_node_type = Root,
    root_node_tf = torch.eye(4)
)
ground_truth_tree = grammar.sample_tree(detach=True)
observed_nodes = ground_truth_tree.get_observed_nodes()
print("Observed %d objects" % len(observed_nodes))
# Out:
# WARNING:root:Detaching BinghamDistribution parameters.
# WARNING:root:Prior over parameters of WorldFrameBinghamRotationRule are Deltas.
# Observed 8 objects

# %%
pyro.set_rng_seed(42)
parse_tree, score = sample_likely_tree_with_greedy_parsing(grammar, observed_nodes, verbose=True)
print("FINAL SCORE: ", score)
# Out:
# WARNING:root:Found no potential parents for orphan set [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7cc0>, <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7e80>, <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940>]
# WARNING:root:Found no potential parents for orphan set [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940>]
# WARNING:root:Found no potential parents for orphan set [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7a20>]
# WARNING:root:Found no potential parents for orphan set [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940>]
# WARNING:root:Found no potential parents for orphan set [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7e80>]
# WARNING:root:Found no potential parents for orphan set [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940>]
# WARNING:root:Found no potential parents for orphan set [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940>]
# Starting setup.
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Root object at 0x7f5f772f7588> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7da0>] [None]
# Taken:  [False False]
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Singles object at 0x7f5f77287208> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7da0>] [None]
# Taken:  [False False False]
# Using ind 0
# Total score from discrete:  tensor(-0.7839)
# Score after child node <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7da0>->0: -8.920931
# Final score:  tensor([-8.9209])
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pairs object at 0x7f5f77402278> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7da0>] [None]
# Taken:  [False False False]
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423a20> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7da0>] [None]
# Taken:  [False False]
# Using ind 0
# Total score from discrete:  tensor(-inf)
# Score after child node <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7da0>->0: -inf
# Final score:  tensor([-inf])
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423c88> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7da0>] [None]
# Taken:  [False False]
# Using ind 0
# Total score from discrete:  tensor(-inf)
# Score after child node <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7da0>->0: -inf
# Final score:  tensor([-inf])
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423f28> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7da0>] [None]
# Taken:  [False False]
# Using ind 0
# Total score from discrete:  tensor(-inf)
# Score after child node <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7da0>->0: -inf
# Final score:  tensor([-inf])
#
#
#
# ****** Adding to node  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Singles object at 0x7f5f77287208>
# 	 <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Singles object at 0x7f5f77287208>-><spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7da0> via rule 0
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Root object at 0x7f5f772f7588> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7cc0>, <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7e80>, <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940>] [None, None, None]
# Taken:  [False False]
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Singles object at 0x7f5f77287208> :
# 	Existing:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7da0>] [0]
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7cc0>, <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7e80>, <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940>] [None, None, None]
# Existing child at rule 0
# Taken:  [ True False False]
# Using ind 1
# Using ind 2
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pairs object at 0x7f5f77402278> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7cc0>, <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7e80>, <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940>] [None, None, None]
# Taken:  [False False False]
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423a20> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7cc0>, <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7e80>, <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940>] [None, None, None]
# Taken:  [False False]
# Using ind 0
# Using ind 1
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423c88> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7cc0>, <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7e80>, <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940>] [None, None, None]
# Taken:  [False False]
# Using ind 0
# Using ind 1
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423f28> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7cc0>, <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7e80>, <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940>] [None, None, None]
# Taken:  [False False]
# Using ind 0
# Using ind 1
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Root object at 0x7f5f772f7588> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7cc0>] [None]
# Taken:  [False False]
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Singles object at 0x7f5f77287208> :
# 	Existing:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7da0>] [0]
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7cc0>] [None]
# Existing child at rule 0
# Taken:  [ True False False]
# Using ind 1
# Total score from discrete:  tensor(-1.1406)
# Score after child node <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7da0>->0: -9.277606
# Score after child node <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7cc0>->1: -16.121057
# Final score:  tensor([-16.1211])
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pairs object at 0x7f5f77402278> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7cc0>] [None]
# Taken:  [False False False]
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423a20> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7cc0>] [None]
# Taken:  [False False]
# Using ind 0
# Total score from discrete:  tensor(-inf)
# Score after child node <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7cc0>->0: -inf
# Final score:  tensor([-inf])
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423c88> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7cc0>] [None]
# Taken:  [False False]
# Using ind 0
# Total score from discrete:  tensor(-inf)
# Score after child node <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7cc0>->0: -inf
# Final score:  tensor([-inf])
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423f28> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7cc0>] [None]
# Taken:  [False False]
# Using ind 0
# Total score from discrete:  tensor(-inf)
# Score after child node <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7cc0>->0: -inf
# Final score:  tensor([-inf])
#
#
#
# ****** Adding to node  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Singles object at 0x7f5f77287208>
# 	 <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Singles object at 0x7f5f77287208>-><spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7cc0> via rule 1
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Root object at 0x7f5f772f7588> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7be0>] [None]
# Taken:  [False False]
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Singles object at 0x7f5f77287208> :
# 	Existing:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7da0>, <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7cc0>] [0, 1]
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7be0>] [None]
# Existing child at rule 0
# Existing child at rule 1
# Taken:  [ True  True False]
# Using ind 2
# Total score from discrete:  tensor(-1.4973)
# Score after child node <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7da0>->0: -9.634281
# Score after child node <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7cc0>->1: -16.477732
# Score after child node <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7be0>->2: -23.222044
# Final score:  tensor([-23.2220])
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pairs object at 0x7f5f77402278> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7be0>] [None]
# Taken:  [False False False]
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423a20> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7be0>] [None]
# Taken:  [False False]
# Using ind 0
# Total score from discrete:  tensor(-inf)
# Score after child node <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7be0>->0: -inf
# Final score:  tensor([-inf])
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423c88> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7be0>] [None]
# Taken:  [False False]
# Using ind 0
# Total score from discrete:  tensor(-inf)
# Score after child node <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7be0>->0: -inf
# Final score:  tensor([-inf])
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423f28> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7be0>] [None]
# Taken:  [False False]
# Using ind 0
# Total score from discrete:  tensor(-inf)
# Score after child node <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7be0>->0: -inf
# Final score:  tensor([-inf])
#
#
#
# ****** Adding to node  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Singles object at 0x7f5f77287208>
# 	 <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Singles object at 0x7f5f77287208>-><spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7be0> via rule 2
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Root object at 0x7f5f772f7588> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940>] [None]
# Taken:  [False False]
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Singles object at 0x7f5f77287208> :
# 	Existing:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7da0>, <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7cc0>, <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7be0>] [0, 1, 2]
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940>] [None]
# Existing child at rule 0
# Existing child at rule 1
# Existing child at rule 2
# Taken:  [ True  True  True]
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pairs object at 0x7f5f77402278> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940>] [None]
# Taken:  [False False False]
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423a20> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940>] [None]
# Taken:  [False False]
# Using ind 0
# Total score from discrete:  tensor(-inf)
# Score after child node <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940>->0: -inf
# Final score:  tensor([-inf])
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423c88> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940>] [None]
# Taken:  [False False]
# Using ind 0
# Total score from discrete:  tensor(-inf)
# Score after child node <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940>->0: -inf
# Final score:  tensor([-inf])
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423f28> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940>] [None]
# Taken:  [False False]
# Using ind 0
# Total score from discrete:  tensor(-inf)
# Score after child node <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940>->0: -inf
# Final score:  tensor([-inf])
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Root object at 0x7f5f772f7588> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7a20>] [None]
# Taken:  [False False]
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Singles object at 0x7f5f77287208> :
# 	Existing:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7da0>, <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7cc0>, <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7be0>] [0, 1, 2]
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7a20>] [None]
# Existing child at rule 0
# Existing child at rule 1
# Existing child at rule 2
# Taken:  [ True  True  True]
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pairs object at 0x7f5f77402278> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7a20>] [None]
# Taken:  [False False False]
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423a20> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7a20>] [None]
# Taken:  [False False]
# Using ind 0
# Total score from discrete:  tensor(-inf)
# Score after child node <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7a20>->0: -inf
# Final score:  tensor([-inf])
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423c88> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7a20>] [None]
# Taken:  [False False]
# Using ind 0
# Total score from discrete:  tensor(-inf)
# Score after child node <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7a20>->0: -inf
# Final score:  tensor([-inf])
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423f28> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7a20>] [None]
# Taken:  [False False]
# Using ind 0
# Total score from discrete:  tensor(-inf)
# Score after child node <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7a20>->0: -inf
# Final score:  tensor([-inf])
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Root object at 0x7f5f772f7588> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940>] [None]
# Taken:  [False False]
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Singles object at 0x7f5f77287208> :
# 	Existing:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7da0>, <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7cc0>, <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7be0>] [0, 1, 2]
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940>] [None]
# Existing child at rule 0
# Existing child at rule 1
# Existing child at rule 2
# Taken:  [ True  True  True]
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pairs object at 0x7f5f77402278> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940>] [None]
# Taken:  [False False False]
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423a20> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940>] [None]
# Taken:  [False False]
# Using ind 0
# Total score from discrete:  tensor(-inf)
# Score after child node <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940>->0: -inf
# Final score:  tensor([-inf])
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423c88> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940>] [None]
# Taken:  [False False]
# Using ind 0
# Total score from discrete:  tensor(-inf)
# Score after child node <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940>->0: -inf
# Final score:  tensor([-inf])
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423f28> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940>] [None]
# Taken:  [False False]
# Using ind 0
# Total score from discrete:  tensor(-inf)
# Score after child node <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940>->0: -inf
# Final score:  tensor([-inf])
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Root object at 0x7f5f772f7588> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7e80>] [None]
# Taken:  [False False]
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Singles object at 0x7f5f77287208> :
# 	Existing:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7da0>, <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7cc0>, <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7be0>] [0, 1, 2]
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7e80>] [None]
# Existing child at rule 0
# Existing child at rule 1
# Existing child at rule 2
# Taken:  [ True  True  True]
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pairs object at 0x7f5f77402278> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7e80>] [None]
# Taken:  [False False False]
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423a20> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7e80>] [None]
# Taken:  [False False]
# Using ind 0
# Total score from discrete:  tensor(-inf)
# Score after child node <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7e80>->0: -inf
# Final score:  tensor([-inf])
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423c88> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7e80>] [None]
# Taken:  [False False]
# Using ind 0
# Total score from discrete:  tensor(-inf)
# Score after child node <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7e80>->0: -inf
# Final score:  tensor([-inf])
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423f28> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7e80>] [None]
# Taken:  [False False]
# Using ind 0
# Total score from discrete:  tensor(-inf)
# Score after child node <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7e80>->0: -inf
# Final score:  tensor([-inf])
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Root object at 0x7f5f772f7588> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940>] [None]
# Taken:  [False False]
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Singles object at 0x7f5f77287208> :
# 	Existing:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7da0>, <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7cc0>, <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7be0>] [0, 1, 2]
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940>] [None]
# Existing child at rule 0
# Existing child at rule 1
# Existing child at rule 2
# Taken:  [ True  True  True]
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pairs object at 0x7f5f77402278> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940>] [None]
# Taken:  [False False False]
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423a20> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940>] [None]
# Taken:  [False False]
# Using ind 0
# Total score from discrete:  tensor(-inf)
# Score after child node <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940>->0: -inf
# Final score:  tensor([-inf])
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423c88> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940>] [None]
# Taken:  [False False]
# Using ind 0
# Total score from discrete:  tensor(-inf)
# Score after child node <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940>->0: -inf
# Final score:  tensor([-inf])
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423f28> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940>] [None]
# Taken:  [False False]
# Using ind 0
# Total score from discrete:  tensor(-inf)
# Score after child node <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940>->0: -inf
# Final score:  tensor([-inf])
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Root object at 0x7f5f772f7588> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940>] [None]
# Taken:  [False False]
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Singles object at 0x7f5f77287208> :
# 	Existing:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7da0>, <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7cc0>, <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7be0>] [0, 1, 2]
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940>] [None]
# Existing child at rule 0
# Existing child at rule 1
# Existing child at rule 2
# Taken:  [ True  True  True]
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pairs object at 0x7f5f77402278> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940>] [None]
# Taken:  [False False False]
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423a20> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940>] [None]
# Taken:  [False False]
# Using ind 0
# Total score from discrete:  tensor(-inf)
# Score after child node <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940>->0: -inf
# Final score:  tensor([-inf])
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423c88> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940>] [None]
# Taken:  [False False]
# Using ind 0
# Total score from discrete:  tensor(-inf)
# Score after child node <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940>->0: -inf
# Final score:  tensor([-inf])
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423f28> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940>] [None]
# Taken:  [False False]
# Using ind 0
# Total score from discrete:  tensor(-inf)
# Score after child node <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940>->0: -inf
# Final score:  tensor([-inf])
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Root object at 0x7f5f772f7588> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7b00>] [None]
# Taken:  [False False]
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Singles object at 0x7f5f77287208> :
# 	Existing:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7da0>, <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7cc0>, <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7be0>] [0, 1, 2]
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7b00>] [None]
# Existing child at rule 0
# Existing child at rule 1
# Existing child at rule 2
# Taken:  [ True  True  True]
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pairs object at 0x7f5f77402278> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7b00>] [None]
# Taken:  [False False False]
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423a20> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7b00>] [None]
# Taken:  [False False]
# Using ind 0
# Total score from discrete:  tensor(-inf)
# Score after child node <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7b00>->0: -inf
# Final score:
# WARNING:root:Found no potential parents for orphan set [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7b00>]
# WARNING:root:Found no potential parents for orphan set [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7b00>]
# WARNING:root:Found no potential parents for orphan set [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7e80>]
# WARNING:root:Found no potential parents for orphan set [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7b00>]
# WARNING:root:Found no potential parents for orphan set [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7b00>]
# WARNING:root:Found no potential parents for orphan set [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7b00>, <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7a20>, <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7e80>]
# WARNING:root:Found no potential parents for orphan set [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7a20>]
# WARNING:root:Found no potential parents for orphan set [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940>]
# WARNING:root:Found no potential parents for orphan set [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423a20>, <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7e80>]
# WARNING:root:Found no potential parents for orphan set [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7e80>]
# WARNING:root:Found no potential parents for orphan set [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940>, <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pairs object at 0x7f5f77402278>, <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7e80>]
# tensor([-inf])
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423c88> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7b00>] [None]
# Taken:  [False False]
# Using ind 0
# Total score from discrete:  tensor(-inf)
# Score after child node <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7b00>->0: -inf
# Final score:  tensor([-inf])
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423f28> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7b00>] [None]
# Taken:  [False False]
# Using ind 0
# Total score from discrete:  tensor(-inf)
# Score after child node <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7b00>->0: -inf
# Final score:  tensor([-inf])
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Root object at 0x7f5f772f7588> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Singles object at 0x7f5f77287208>] [None]
# Taken:  [False False]
# Using ind 0
# Total score from discrete:  tensor(-1.8326)
# Score after child node <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Singles object at 0x7f5f77287208>->0: -1.832581
# Final score:  tensor(-1.8326)
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pairs object at 0x7f5f77402278> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Singles object at 0x7f5f77287208>] [None]
# Taken:  [False False False]
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423a20> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Singles object at 0x7f5f77287208>] [None]
# Taken:  [False False]
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423c88> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Singles object at 0x7f5f77287208>] [None]
# Taken:  [False False]
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423f28> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Singles object at 0x7f5f77287208>] [None]
# Taken:  [False False]
#
#
#
# ****** Adding to node  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Root object at 0x7f5f772f7588>
# 	 <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Root object at 0x7f5f772f7588>-><spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Singles object at 0x7f5f77287208> via rule 0
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Root object at 0x7f5f772f7588> :
# 	Existing:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Singles object at 0x7f5f77287208>] [0]
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7b00>] [None]
# Existing child at rule 0
# Taken:  [ True False]
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Singles object at 0x7f5f77287208> :
# 	Existing:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7da0>, <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7cc0>, <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7be0>] [0, 1, 2]
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7b00>] [None]
# Existing child at rule 0
# Existing child at rule 1
# Existing child at rule 2
# Taken:  [ True  True  True]
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pairs object at 0x7f5f77402278> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7b00>] [None]
# Taken:  [False False False]
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423a20> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7b00>] [None]
# Taken:  [False False]
# Using ind 0
# Total score from discrete:  tensor(-inf)
# Score after child node <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7b00>->0: -inf
# Final score:  tensor([-inf])
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423c88> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7b00>] [None]
# Taken:  [False False]
# Using ind 0
# Total score from discrete:  tensor(-inf)
# Score after child node <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7b00>->0: -inf
# Final score:  tensor([-inf])
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423f28> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7b00>] [None]
# Taken:  [False False]
# Using ind 0
# Total score from discrete:  tensor(-inf)
# Score after child node <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7b00>->0: -inf
# Final score:  tensor([-inf])
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Root object at 0x7f5f772f7588> :
# 	Existing:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Singles object at 0x7f5f77287208>] [0]
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7e80>] [None]
# Existing child at rule 0
# Taken:  [ True False]
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Singles object at 0x7f5f77287208> :
# 	Existing:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7da0>, <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7cc0>, <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7be0>] [0, 1, 2]
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7e80>] [None]
# Existing child at rule 0
# Existing child at rule 1
# Existing child at rule 2
# Taken:  [ True  True  True]
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pairs object at 0x7f5f77402278> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7e80>] [None]
# Taken:  [False False False]
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423a20> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7e80>] [None]
# Taken:  [False False]
# Using ind 0
# Total score from discrete:  tensor(-inf)
# Score after child node <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7e80>->0: -inf
# Final score:  tensor([-inf])
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423c88> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7e80>] [None]
# Taken:  [False False]
# Using ind 0
# Total score from discrete:  tensor(-inf)
# Score after child node <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7e80>->0: -inf
# Final score:  tensor([-inf])
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423f28> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7e80>] [None]
# Taken:  [False False]
# Using ind 0
# Total score from discrete:  tensor(-inf)
# Score after child node <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7e80>->0: -inf
# Final score:  tensor([-inf])
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Root object at 0x7f5f772f7588> :
# 	Existing:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Singles object at 0x7f5f77287208>] [0]
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7b00>] [None]
# Existing child at rule 0
# Taken:  [ True False]
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Singles object at 0x7f5f77287208> :
# 	Existing:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7da0>, <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7cc0>, <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7be0>] [0, 1, 2]
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7b00>] [None]
# Existing child at rule 0
# Existing child at rule 1
# Existing child at rule 2
# Taken:  [ True  True  True]
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pairs object at 0x7f5f77402278> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7b00>] [None]
# Taken:  [False False False]
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423a20> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7b00>] [None]
# Taken:  [False False]
# Using ind 0
# Total score from discrete:  tensor(-inf)
# Score after child node <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7b00>->0: -inf
# Final score:  tensor([-inf])
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423c88> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7b00>] [None]
# Taken:  [False False]
# Using ind 0
# Total score from discrete:  tensor(-inf)
# Score after child node <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7b00>->0: -inf
# Final score:  tensor([-inf])
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423f28> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7b00>] [None]
# Taken:  [False False]
# Using ind 0
# Total score from discrete:  tensor(-inf)
# Score after child node <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7b00>->0: -inf
# Final score:  tensor([-inf])
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Root object at 0x7f5f772f7588> :
# 	Existing:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Singles object at 0x7f5f77287208>] [0]
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7b00>] [None]
# Existing child at rule 0
# Taken:  [ True False]
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Singles object at 0x7f5f77287208> :
# 	Existing:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7da0>, <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7cc0>, <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7be0>] [0, 1, 2]
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7b00>] [None]
# Existing child at rule 0
# Existing child at rule 1
# Existing child at rule 2
# Taken:  [ True  True  True]
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pairs object at 0x7f5f77402278> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7b00>] [None]
# Taken:  [False False False]
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423a20> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7b00>] [None]
# Taken:  [False False]
# Using ind 0
# ...
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pairs object at 0x7f5f77402278>] [None]
# Existing child at rule 0
# Existing child at rule 1
# Existing child at rule 2
# Taken:  [ True  True  True]
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423a20> :
# 	Existing:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7b00>, <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7a20>] [0, 1]
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pairs object at 0x7f5f77402278>] [None]
# Existing child at rule 0
# Existing child at rule 1
# Taken:  [ True  True]
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423c88> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pairs object at 0x7f5f77402278>] [None]
# Taken:  [False False]
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423f28> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pairs object at 0x7f5f77402278>] [None]
# Taken:  [False False]
#
#
#
# ****** Adding to node  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Root object at 0x7f5f772f7588>
# 	 <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Root object at 0x7f5f772f7588>-><spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pairs object at 0x7f5f77402278> via rule 1
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Root object at 0x7f5f772f7588> :
# 	Existing:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Singles object at 0x7f5f77287208>, <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pairs object at 0x7f5f77402278>] [0, 1]
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940>] [None]
# Existing child at rule 0
# Existing child at rule 1
# Taken:  [ True  True]
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Singles object at 0x7f5f77287208> :
# 	Existing:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7da0>, <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7cc0>, <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7be0>] [0, 1, 2]
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940>] [None]
# Existing child at rule 0
# Existing child at rule 1
# Existing child at rule 2
# Taken:  [ True  True  True]
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423a20> :
# 	Existing:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7b00>, <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7a20>] [0, 1]
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940>] [None]
# Existing child at rule 0
# Existing child at rule 1
# Taken:  [ True  True]
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pairs object at 0x7f5f77402278> :
# 	Existing:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423a20>] [0]
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940>] [None]
# Existing child at rule 0
# Taken:  [ True False False]
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423c88> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940>] [None]
# Taken:  [False False]
# Using ind 0
# Total score from discrete:  tensor(-inf)
# Score after child node <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940>->0: -inf
# Final score:  tensor([-inf])
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423f28> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940>] [None]
# Taken:  [False False]
# Using ind 0
# Total score from discrete:  tensor(-inf)
# Score after child node <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940>->0: -inf
# Final score:  tensor([-inf])
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Root object at 0x7f5f772f7588> :
# 	Existing:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Singles object at 0x7f5f77287208>, <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pairs object at 0x7f5f77402278>] [0, 1]
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940>] [None]
# Existing child at rule 0
# Existing child at rule 1
# Taken:  [ True  True]
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Singles object at 0x7f5f77287208> :
# 	Existing:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7da0>, <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7cc0>, <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7be0>] [0, 1, 2]
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940>] [None]
# Existing child at rule 0
# Existing child at rule 1
# Existing child at rule 2
# Taken:  [ True  True  True]
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423a20> :
# 	Existing:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7b00>, <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7a20>] [0, 1]
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940>] [None]
# Existing child at rule 0
# Existing child at rule 1
# Taken:  [ True  True]
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pairs object at 0x7f5f77402278> :
# 	Existing:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423a20>] [0]
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940>] [None]
# Existing child at rule 0
# Taken:  [ True False False]
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423c88> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940>] [None]
# Taken:  [False False]
# Using ind 0
# Total score from discrete:  tensor(-inf)
# Score after child node <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940>->0: -inf
# Final score:  tensor([-inf])
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423f28> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940>] [None]
# Taken:  [False False]
# Using ind 0
# Total score from discrete:  tensor(-inf)
# Score after child node <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940>->0: -inf
# Final score:  tensor([-inf])
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Root object at 0x7f5f772f7588> :
# 	Existing:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Singles object at 0x7f5f77287208>, <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pairs object at 0x7f5f77402278>] [0, 1]
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7e80>, <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940>] [None, None]
# Existing child at rule 0
# Existing child at rule 1
# Taken:  [ True  True]
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Singles object at 0x7f5f77287208> :
# 	Existing:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7da0>, <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7cc0>, <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7be0>] [0, 1, 2]
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7e80>, <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940>] [None, None]
# Existing child at rule 0
# Existing child at rule 1
# Existing child at rule 2
# Taken:  [ True  True  True]
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423a20> :
# 	Existing:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7b00>, <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7a20>] [0, 1]
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7e80>, <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940>] [None, None]
# Existing child at rule 0
# Existing child at rule 1
# Taken:  [ True  True]
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pairs object at 0x7f5f77402278> :
# 	Existing:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423a20>] [0]
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7e80>, <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940>] [None, None]
# Existing child at rule 0
# Taken:  [ True False False]
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423c88> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7e80>, <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940>] [None, None]
# Taken:  [False False]
# Using ind 0
# Using ind 1
# Total score from discrete:  tensor(0.)
# Score after child node <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7e80>->0: -715.116244
# Score after child node <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940>->1: -1123.021889
# Final score:  tensor([-1123.0219])
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423f28> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7e80>, <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940>] [None, None]
# Taken:  [False False]
# Using ind 0
# Using ind 1
# Total score from discrete:  tensor(0.)
# Score after child node <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7e80>->0: -744.879113
# Score after child node <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940>->1: -1419.103801
# Final score:  tensor([-1419.1038])
# tensor([ 1.0000e+00, 2.5898e-129]) tensor(0)
#
#
#
# ****** Adding to node  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423c88>
# 	 <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423c88>-><spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7e80> via rule 0
# 	 <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423c88>-><spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7940> via rule 1
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Root object at 0x7f5f772f7588> :
# 	Existing:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Singles object at 0x7f5f77287208>, <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pairs object at 0x7f5f77402278>] [0, 1]
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423c88>] [None]
# Existing child at rule 0
# Existing child at rule 1
# Taken:  [ True  True]
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Singles object at 0x7f5f77287208> :
# 	Existing:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7da0>, <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7cc0>, <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7be0>] [0, 1, 2]
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423c88>] [None]
# Existing child at rule 0
# Existing child at rule 1
# Existing child at rule 2
# Taken:  [ True  True  True]
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423a20> :
# 	Existing:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7b00>, <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Object object at 0x7f5f772f7a20>] [0, 1]
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423c88>] [None]
# Existing child at rule 0
# Existing child at rule 1
# Taken:  [ True  True]
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pairs object at 0x7f5f77402278> :
# 	Existing:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423a20>] [0]
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423c88>] [None]
# Existing child at rule 0
# Taken:  [ True False False]
# Using ind 1
# Total score from discrete:  tensor(-1.1406)
# Score after child node <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423a20>->0: -7.408050
# Score after child node <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423c88>->1: -15.705407
# Final score:  tensor([-15.7054])
# Considering addition to  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423f28> :
# 	Existing:  [] []
# 	New:  [<spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423c88>] [None]
# Taken:  [False False]
#
#
#
# ****** Adding to node  <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pairs object at 0x7f5f77402278>
# 	 <spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pairs object at 0x7f5f77402278>-><spatial_scene_grammars_examples.singles_pairs.grammar_constituency.Pair object at 0x7f5f77423c88> via rule 1
# FINAL SCORE:  tensor([-1372.6321])
