# %%
# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
import os
import pickle
import time
from tqdm.notebook import tqdm

import torch
torch.set_default_tensor_type(torch.DoubleTensor)

from spatial_scene_grammars.nodes import *
from spatial_scene_grammars.rules import *
from spatial_scene_grammars.scene_grammar import *
from spatial_scene_grammars.visualization import *
from spatial_scene_grammars_examples.table.grammar import *
from spatial_scene_grammars.parsing import *
from spatial_scene_grammars.sampling import *
from spatial_scene_grammars.parameter_estimation import *
from spatial_scene_grammars.dataset import *

import meshcat
import meshcat.geometry as meshcat_geom

# %%
if 'vis' not in globals():
    vis = meshcat.Visualizer()
vis.delete()
base_url = "http://127.0.0.1"
meshcat_url = base_url + ":" + vis.url().split(":")[-1]
print("Meshcat url: ", meshcat_url)
'''
from IPython.display import HTML
HTML("""
    <div style="height: 400px; width: 100%; overflow-x: auto; overflow-y: hidden; resize: both">
    <iframe src="{url}" style="width: 100%; height: 100%; border: none"></iframe>
</div>
""".format(url=meshcat_url))
'''
# Out:
# You can open the visualizer by visiting the following URL:
# http://127.0.0.1:7005/static/
# Meshcat url:  http://127.0.0.1:7005/static/
# '\nfrom IPython.display import HTML\nHTML("""\n    <div style="height: 400px; width: 100%; overflow-x: auto; overflow-y: hidden; resize: both">\n    <iframe src="{url}" style="width: 100%; height: 100%; border: none"></iframe>\n</div>\n""".format(url=meshcat_url))\n'

# %%
# Set up grammar
grammar = SpatialSceneGrammar(
    root_node_type = Table,
    root_node_tf = drake_tf_to_torch_tf(RigidTransform(p=[0.0, 0., 0.8]))
)
# Out:
# WARNING:root:Detaching BinghamDistribution parameters.
# WARNING:root:Prior over parameters of WorldFrameBinghamRotationRule are Deltas.

# %%
# Constraints
constraints = [
    ObjectsOnTableConstraint(),
    ObjectSpacingConstraint(),
    TallStackConstraint()
]

# Sample a tree that satisfies the discrete constraints
max_attempts = 1000
tree, success = rejection_sample_under_constraints(
    grammar, [c for c in constraints if isinstance(c, StructureConstraint)],
    max_num_attempts=max_attempts, detach=True
)
if not success:
    logging.error("Didn't sample a good tree in %d attempts." % max_attempts)
hmc_tree = deepcopy(tree)
samples = do_fixed_structure_hmc_with_constraint_penalties(
    grammar, hmc_tree, num_samples=50, subsample_step=5,
    with_nonpenetration=False, zmq_url=vis.window.zmq_url,
    constraints=constraints,
    kernel_type="NUTS", max_tree_depth=6, target_accept_prob=0.8, step_size=1E-2, adapt_step_size=True,
    #kernel_type="HMC", num_steps=1, step_size=1E-4, adapt_step_size=False # Langevin-ish
)
# Out:
# 0 tensor(inf)
# 1 tensor(3.)
# 9 tensor(1.)
# 51 tensor(1.)
# [2022-01-24 16:55:59.656] [console] [warning] FindResource ignoring DRAKE_RESOURCE_ROOT='/home/gizatt/drake' because it does not contain a 'drake' subdirectory.
# Initial trace log prob:  tensor(-4080.4869)
# Connecting to meshcat-server at zmq_url=tcp://127.0.0.1:6005...
# You can open the visualizer by visiting the following URL:
# http://127.0.0.1:7005/static/
# Connected to meshcat-server.
# Warmup:   0%|          | 0/75 [00:00, ?it/s]WARNING:root:NormalizeWithPseudoInverse LogAbsDet is super sketchy
# Sample: 100%|██████████| 75/75 [02:04,  1.66s/it, step size=9.69e-02, acc. prob=0.286]

# %%
k=0
draw_scene_tree_contents_meshcat(samples[-k], zmq_url=vis.window.zmq_url,  prefix="hmc_samples/%d/contents" % k)
draw_scene_tree_structure_meshcat(samples[-k], zmq_url=vis.window.zmq_url,  prefix="hmc_samples/%d/structure" % k)

# %%
# Do final projeciton pass
final_tree = project_tree_to_feasibility(samples[-k], do_forward_sim=True, timestep=0.001, T=1.)
draw_scene_tree_contents_meshcat(samples[-k], zmq_url=vis.window.zmq_url,  prefix="final_sample/contents")
draw_scene_tree_structure_meshcat(samples[-k], zmq_url=vis.window.zmq_url,  prefix="final_sample/structure")

# %%
# Save that scene out for use in another notebook
with open("example_feasible_sampled_scene.pickle", "wb") as f:
    pickle.dump(final_tree, f)

# %% [markdown]
# # Random single scene parsing test

# %%
print("Ground truth tree score: ", tree.score())
# Out:
# Ground truth tree score:  tensor([-82.7861])

# %%
# Try to parse "tree" sampled above
# Parse it with IP.
vis["ip_parses"].delete()
supertree = grammar.make_super_tree(max_recursion_depth=10)
print("Supertree size ", len(supertree.nodes))

observed_nodes = tree.get_observed_nodes()
proposed_poses_by_type = generate_candidate_node_pose_sets(
    grammar, observed_nodes, max_recursion_depth=10, verbose=True
)
parse_trees = infer_mle_tree_with_mip_from_proposals(
    grammar, observed_nodes, {}, verbose=2, N_solutions=4
)
parse_tree = parse_trees[0]
for k, parse_tree in enumerate(parse_trees[:1]):
    score = parse_tree.score()
    print("SOL #%d: SCORE %f" % (k, score))
    draw_scene_tree_structure_meshcat(parse_tree, zmq_url=vis.window.zmq_url, prefix="ip_parses/%d_%f" % (k, score), linewidth=20, with_triad=False, node_sphere_size=0.025, alpha=0.5)
# Out:
# Supertree size  88
# 12 top-down candidates.
# 24 bottom-up candidates.
# Post final pruning:  36
# Optimization success?:  True
# Logfile:
#
# Gurobi 9.0.2 (linux64) logging started Mon Jan 17 20:47:17 2022
#
# Gurobi Optimizer version 9.0.2 build v9.0.2rc0 (linux64)
# Optimize a model with 1206 rows, 843 columns and 3838 nonzeros
# Model fingerprint: 0xb721da2b
# Variable types: 0 continuous, 843 integer (843 binary)
# Coefficient statistics:
#   Matrix range     [2e-02, 1e+00]
#   Objective range  [7e-01, 5e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e-02, 1e+00]
# Presolve removed 1185 rows and 803 columns
# Presolve time: 0.01s
# Presolved: 21 rows, 40 columns, 77 nonzeros
# Variable types: 0 continuous, 40 integer (40 binary)
# Found heuristic solution: objective 82.7861243
#
# Root relaxation: objective 8.278612e+01, 4 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0        82.78612   82.78612  0.00%     -    0s
#
# Optimal solution found at node 0 - now completing solution pool...
#
#     Nodes    |    Current Node    |      Pool Obj. Bounds     |     Work
#              |                    |   Worst                   |
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0               -   82.78612      -     -    0s
#      0     0          -    0               -   82.78612      -     -    0s
#      0     2          -    0               -   82.78612      -     -    0s
#
# Explored 78 nodes (41 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 4: 82.7861 154.69 174.783 199.043
# No other solutions better than 199.043
#
# Optimal solution found (tolerance 1.00e-03)
# Best objective 8.278612432326e+01, best bound 8.278612432326e+01, gap 0.0000%
#
# Building tree for sol 0...
# Node <spatial_scene_grammars_examples.table.grammar.Table object at 0x7f16248f2eb8> getting tf tensor([[1.0000, 0.0000, 0.0000, 0.0000],
#         [0.0000, 1.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 1.0000, 0.8000],
#         [0.0000, 0.0000, 0.0000, 1.0000]])
# Node <spatial_scene_grammars_examples.table.grammar.PlaceSettings object at 0x7f16242460f0> getting tf tensor([[1.0000, 0.0000, 0.0000, 0.0000],
#         [0.0000, 1.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 1.0000, 0.8250],
#         [0.0000, 0.0000, 0.0000, 1.0000]])
# Added Table_1791--(0)>PlaceSettings_1766
# Node <spatial_scene_grammars_examples.table.grammar.SharedStuff object at 0x7f1624246e10> getting tf tensor([[1.0000, 0.0000, 0.0000, 0.0000],
#         [0.0000, 1.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 1.0000, 0.8250],
#         [0.0000, 0.0000, 0.0000, 1.0000]])
# Added Table_1791--(1)>SharedStuff_1766
# Node <spatial_scene_grammars_examples.table.grammar.PlaceSetting object at 0x7f16242464e0> getting tf tensor([[ 1.0000,  0.0000,  0.0000, -0.5000],
#         [ 0.0000,  1.0000,  0.0000,  0.0000],
#         [ 0.0000,  0.0000,  1.0000,  0.8250],
#         [ 0.0000,  0.0000,  0.0000,  1.0000]])
# Added PlaceSettings_1766--(0)>PlaceSetting_2117
# Node <spatial_scene_grammars_examples.table.grammar.PlaceSetting object at 0x7f1624848390> getting tf tensor([[-1.0000e+00, -1.2246e-16,  0.0000e+00,  5.0000e-01],
#         [ 1.2246e-16, -1.0000e+00,  0.0000e+00,  0.0000e+00],
#         [ 0.0000e+00,  0.0000e+00,  1.0000e+00,  8.2500e-01],
#         [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]])
# Added PlaceSettings_1766--(1)>PlaceSetting_2118
# Node <spatial_scene_grammars_examples.table.grammar.PlaceSetting object at 0x7f15a43a30f0> getting tf tensor([[ 6.1232e-17,  1.0000e+00,  0.0000e+00,  0.0000e+00],
#         [-1.0000e+00,  6.1232e-17,  0.0000e+00,  5.0000e-01],
#         [ 0.0000e+00,  0.0000e+00,  1.0000e+00,  8.2500e-01],
#         [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]])
# Added PlaceSettings_1766--(2)>PlaceSetting_2119
# Node <spatial_scene_grammars_examples.table.grammar.PlaceSetting object at 0x7f15a43a3c18> getting tf tensor([[ 6.1232e-17, -1.0000e+00,  0.0000e+00,  0.0000e+00],
#         [ 1.0000e+00,  6.1232e-17,  0.0000e+00, -5.0000e-01],
#         [ 0.0000e+00,  0.0000e+00,  1.0000e+00,  8.2500e-01],
#         [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]])
# Added PlaceSettings_1766--(3)>PlaceSetting_2120
# Node <spatial_scene_grammars_examples.table.grammar.SharedTeapots object at 0x7f15a43a39e8> getting tf tensor([[1.0000, 0.0000, 0.0000, 0.0000],
#         [0.0000, 1.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 1.0000, 0.8250],
#         [0.0000, 0.0000, 0.0000, 1.0000]])
# Added SharedStuff_1766--(0)>SharedTeapots_1766
# Node <spatial_scene_grammars_examples.table.grammar.SharedDishes object at 0x7f15a43a35c0> getting tf tensor([[1.0000, 0.0000, 0.0000, 0.0000],
#         [0.0000, 1.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 1.0000, 0.8250],
#         [0.0000, 0.0000, 0.0000, 1.0000]])
# Added SharedStuff_1766--(1)>SharedDishes_1766
# Node <spatial_scene_grammars_examples.table.grammar.SharedSteamers object at 0x7f16242670b8> getting tf tensor([[1.0000, 0.0000, 0.0000, 0.0000],
#         [0.0000, 1.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 1.0000, 0.8250],
#         [0.0000, 0.0000, 0.0000, 1.0000]])
# Added SharedStuff_1766--(2)>SharedSteamers_1766
# Node <spatial_scene_grammars_examples.table.grammar.PersonalPlate object at 0x7f162488b588> getting tf tensor([[ 0.8506, -0.5258, -0.0012, -0.4718],
#         [ 0.5250,  0.8493,  0.0558, -0.0210],
#         [-0.0283, -0.0481,  0.9984,  0.7953],
#         [ 0.0000,  0.0000,  0.0000,  1.0000]])
# Added PlaceSetting_2117--(0)>PersonalPlate_2156
# Node <spatial_scene_grammars_examples.table.grammar.Teacup object at 0x7f162488b5f8> getting tf tensor([[-0.1324, -0.9911,  0.0105, -0.1901],
#         [ 0.9887, -0.1313,  0.0720, -0.0099],
#         [-0.0700,  0.0199,  0.9973,  0.8328],
#         [ 0.0000,  0.0000,  0.0000,  1.0000]])
# Added PlaceSetting_2117--(1)>Teacup_2217
# Node <spatial_scene_grammars_examples.table.grammar.Teacup object at 0x7f162488b240> getting tf tensor([[-0.4254, -0.9008,  0.0870,  0.2702],
#         [ 0.9042, -0.4272, -0.0019, -0.0168],
#         [ 0.0389,  0.0779,  0.9962,  0.8213],
#         [ 0.0000,  0.0000,  0.0000,  1.0000]])
# Added PlaceSetting_2118--(1)>Teacup_2218
# Node <spatial_scene_grammars_examples.table.grammar.PersonalPlate object at 0x7f162488b0f0> getting tf tensor([[-0.9498, -0.3014, -0.0844,  0.0171],
#         [ 0.3013, -0.9534,  0.0137,  0.4378],
#         [-0.0846, -0.0124,  0.9963,  0.8278],
#         [ 0.0000,  0.0000,  0.0000,  1.0000]])
# Added PlaceSetting_2119--(0)>PersonalPlate_2157
# Node <spatial_scene_grammars_examples.table.grammar.Teacup object at 0x7f162488bd68> getting tf tensor([[-0.7329, -0.6803,  0.0084, -0.0123],
#         [ 0.6802, -0.7325,  0.0267,  0.2589],
#         [-0.0120,  0.0252,  0.9996,  0.8176],
#         [ 0.0000,  0.0000,  0.0000,  1.0000]])
# Added PlaceSetting_2119--(1)>Teacup_2219
# Node <spatial_scene_grammars_examples.table.grammar.PersonalPlate object at 0x7f162488bd30> getting tf tensor([[-0.2768, -0.9599, -0.0442,  0.0576],
#         [ 0.9606, -0.2752, -0.0383, -0.5366],
#         [ 0.0246, -0.0531,  0.9983,  0.8325],
#         [ 0.0000,  0.0000,  0.0000,  1.0000]])
# Added PlaceSetting_2120--(0)>PersonalPlate_2158
# Node <spatial_scene_grammars_examples.table.grammar.Teacup object at 0x7f162488b048> getting tf tensor([[-0.9961,  0.0246, -0.0848, -0.0851],
#         [-0.0221, -0.9993, -0.0294, -0.2046],
#         [-0.0855, -0.0274,  0.9960,  0.8351],
#         [ 0.0000,  0.0000,  0.0000,  1.0000]])
# Added PlaceSetting_2120--(1)>Teacup_2220
# Node <spatial_scene_grammars_examples.table.grammar.Teapot object at 0x7f162488b278> getting tf tensor([[-0.9937,  0.0940, -0.0613,  0.0657],
#         [-0.0973, -0.9939,  0.0526,  0.2726],
#         [-0.0560,  0.0583,  0.9967,  0.8244],
#         [ 0.0000,  0.0000,  0.0000,  1.0000]])
# Added SharedTeapots_1766--(0)>Teapot_1872
# Node <spatial_scene_grammars_examples.table.grammar.ServingDish object at 0x7f162488b080> getting tf tensor([[-0.9238,  0.3829,  0.0059,  0.0865],
#         [-0.3822, -0.9227,  0.0501,  0.0173],
#         [ 0.0247,  0.0440,  0.9987,  0.8428],
#         [ 0.0000,  0.0000,  0.0000,  1.0000]])
# Added SharedDishes_1766--(0)>ServingDish_1872
# Node <spatial_scene_grammars_examples.table.grammar.SteamerBottom object at 0x7f162488b8d0> getting tf tensor([[ 0.9989,  0.0477,  0.0034, -0.2122],
#         [-0.0478,  0.9986,  0.0230,  0.1042],
#         [-0.0023, -0.0231,  0.9997,  0.8121],
#         [ 0.0000,  0.0000,  0.0000,  1.0000]])
# Added SharedSteamers_1766--(0)>SteamerBottom_3292
# Node <spatial_scene_grammars_examples.table.grammar.SteamerBottom object at 0x7f162488bc18> getting tf tensor([[ 8.4349e-01,  5.3568e-01, -3.9545e-02,  2.3123e-02],
#         [-5.3714e-01,  8.4126e-01, -6.1299e-02,  1.9116e-01],
#         [ 4.3083e-04,  7.2947e-02,  9.9734e-01,  8.3532e-01],
#         [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]])
# Added SharedSteamers_1766--(1)>SteamerBottom_3293
# Node <spatial_scene_grammars_examples.table.grammar.SteamerBottom object at 0x7f162488be80> getting tf tensor([[ 0.9726,  0.2309, -0.0279,  0.0291],
#         [-0.2306,  0.9730,  0.0142, -0.0620],
#         [ 0.0304, -0.0073,  0.9995,  0.8236],
#         [ 0.0000,  0.0000,  0.0000,  1.0000]])
# Added SharedSteamers_1766--(2)>SteamerBottom_3294
# Node <spatial_scene_grammars_examples.table.grammar.SteamerTop object at 0x7f16242785f8> getting tf tensor([[-0.7165,  0.6976, -0.0020, -0.2008],
#         [-0.6971, -0.7159,  0.0387,  0.1200],
#         [ 0.0256,  0.0291,  0.9992,  0.9190],
#         [ 0.0000,  0.0000,  0.0000,  1.0000]])
# Added SteamerBottom_3292--(1)>SteamerTop_3047
# Node <spatial_scene_grammars_examples.table.grammar.SteamerTop object at 0x7f16242782b0> getting tf tensor([[ 0.8329,  0.5524, -0.0341,  0.0124],
#         [-0.5532,  0.8288, -0.0838,  0.1797],
#         [-0.0180,  0.0887,  0.9959,  0.9360],
#         [ 0.0000,  0.0000,  0.0000,  1.0000]])
# Added SteamerBottom_3293--(1)>SteamerTop_3048
# Node <spatial_scene_grammars_examples.table.grammar.SteamerTop object at 0x7f15a1f88c18> getting tf tensor([[ 0.4591,  0.8882, -0.0158,  0.0303],
#         [-0.8879,  0.4594,  0.0257, -0.0565],
#         [ 0.0301,  0.0022,  0.9995,  0.9253],
#         [ 0.0000,  0.0000,  0.0000,  1.0000]])
# Added SteamerBottom_3294--(1)>SteamerTop_3049
# Building tree for sol 1...
# Node <spatial_scene_grammars_examples.table.grammar.Table object at 0x7f16248f2eb8> getting tf tensor([[1.0000, 0.0000, 0.0000, 0.0000],
#         [0.0000, 1.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 1.0000, 0.8000],
#         [0.0000, 0.0000, 0.0000, 1.0000]])
# Node <spatial_scene_grammars_examples.table.grammar.PlaceSettings object at 0x7f16242460f0> getting tf tensor([[1.0000, 0.0000, 0.0000, 0.0000],
#         [0.0000, 1.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 1.0000, 0.8250],
#         [0.0000, 0.0000, 0.0000, 1.0000]])
# Added Table_1792--(0)>PlaceSettings_1767
# Node <spatial_scene_grammars_examples.table.grammar.SharedStuff object at 0x7f1624246e10> getting tf tensor([[1.0000, 0.0000, 0.0000, 0.0000],
#         [0.0000, 1.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 1.0000, 0.8250],
#         [0.0000, 0.0000, 0.0000, 1.0000]])
# Added Table_1792--(1)>SharedStuff_1767
# Node <spatial_scene_grammars_examples.table.grammar.PlaceSetting object at 0x7f16242464e0> getting tf tensor([[ 1.0000,  0.0000,  0.0000, -0.5000],
#         [ 0.0000,  1.0000,  0.0000,  0.0000],
#         [ 0.0000,  0.0000,  1.0000,  0.8250],
#         [ 0.0000,  0.0000,  0.0000,  1.0000]])
# Added PlaceSettings_1767--(0)>PlaceSetting_2121
# Node <spatial_scene_grammars_examples.table.grammar.PlaceSetting object at 0x7f1624848390> getting tf tensor([[-1.0000e+00, -1.2246e-16,  0.0000e+00,  5.0000e-01],
#         [ 1.2246e-16, -1.0000e+00,  0.0000e+00,  0.0000e+00],
#         [ 0.0000e+00,  0.0000e+00,  1.0000e+00,  8.2500e-01],
#         [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]])
# Added PlaceSettings_1767--(1)>PlaceSetting_2122
# Node <spatial_scene_grammars_examples.table.grammar.PlaceSetting object at 0x7f15a43a30f0> getting tf tensor([[ 6.1232e-17,  1.0000e+00,  0.0000e+00,  0.0000e+00],
#         [-1.0000e+00,  6.1232e-17,  0.0000e+00,  5.0000e-01],
#         [ 0.0000e+00,  0.0000e+00,  1.0000e+00,  8.2500e-01],
#         [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]])
# Added PlaceSettings_1767--(2)>PlaceSetting_2123
# Node <spatial_scene_grammars_examples.table.grammar.PlaceSetting object at 0x7f15a43a3c18> getting tf tensor([[ 6.1232e-17, -1.0000e+00,  0.0000e+00,  0.0000e+00],
#         [ 1.0000e+00,  6.1232e-17,  0.0000e+00, -5.0000e-01],
#         [ 0.0000e+00,  0.0000e+00,  1.0000e+00,  8.2500e-01],
#         [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]])
# Added PlaceSettings_1767--(3)>PlaceSetting_2124
# Node <spatial_scene_grammars_examples.table.grammar.SharedTeapots object at 0x7f15a43a39e8> getting tf tensor([[1.0000, 0.0000, 0.0000, 0.0000],
#         [0.0000, 1.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 1.0000, 0.8250],
#         [0.0000, 0.0000, 0.0000, 1.0000]])
# Added SharedStuff_1767--(0)>SharedTeapots_1767
# Node <spatial_scene_grammars_examples.table.grammar.SharedDishes object at 0x7f15a43a35c0> getting tf tensor([[1.0000, 0.0000, 0.0000, 0.0000],
#         [0.0000, 1.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 1.0000, 0.8250],
#         [0.0000, 0.0000, 0.0000, 1.0000]])
# Added SharedStuff_1767--(1)>SharedDishes_1767
# Node <spatial_scene_grammars_examples.table.grammar.SharedSteamers object at 0x7f16242670b8> getting tf tensor([[1.0000, 0.0000, 0.0000, 0.0000],
#         [0.0000, 1.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 1.0000, 0.8250],
#         [0.0000, 0.0000, 0.0000, 1.0000]])
# Added SharedStuff_1767--(2)>SharedSteamers_1767
# Node <spatial_scene_grammars_examples.table.grammar.PersonalPlate object at 0x7f162488b588> getting tf tensor([[ 0.8506, -0.5258, -0.0012, -0.4718],
#         [ 0.5250,  0.8493,  0.0558, -0.0210],
#         [-0.0283, -0.0481,  0.9984,  0.7953],
#         [ 0.0000,  0.0000,  0.0000,  1.0000]])
# Added PlaceSetting_2121--(0)>PersonalPlate_2159
# Node <spatial_scene_grammars_examples.table.grammar.Teacup object at 0x7f162488b5f8> getting tf tensor([[-0.9961,  0.0246, -0.0848, -0.0851],
#         [-0.0221, -0.9993, -0.0294, -0.2046],
#         [-0.0855, -0.0274,  0.9960,  0.8351],
#         [ 0.0000,  0.0000,  0.0000,  1.0000]])
# Added PlaceSetting_2121--(1)>Teacup_2221
# Node <spatial_scene_grammars_examples.table.grammar.Teacup object at 0x7f162488b240> getting tf tensor([[-0.4254, -0.9008,  0.0870,  0.2702],
#         [ 0.9042, -0.4272, -0.0019, -0.0168],
#         [ 0.0389,  0.0779,  0.9962,  0.8213],
#         [ 0.0000,  0.0000,  0.0000,  1.0000]])
# Added PlaceSetting_2122--(1)>Teacup_2222
# Node <spatial_scene_grammars_examples.table.grammar.PersonalPlate object at 0x7f162488b0f0> getting tf tensor([[-0.9498, -0.3014, -0.0844,  0.0171],
#         [ 0.3013, -0.9534,  0.0137,  0.4378],
#         [-0.0846, -0.0124,  0.9963,  0.8278],
#         [ 0.0000,  0.0000,  0.0000,  1.0000]])
# Added PlaceSetting_2123--(0)>PersonalPlate_2160
# Node <spatial_scene_grammars_examples.table.grammar.Teacup object at 0x7f162488bd68> getting tf tensor([[-0.7329, -0.6803,  0.0084, -0.0123],
#         [ 0.6802, -0.7325,  0.0267,  0.2589],
#         [-0.0120,  0.0252,  0.9996,  0.8176],
#         [ 0.0000,  0.0000,  0.0000,  1.0000]])
# Added PlaceSetting_2123--(1)>Teacup_2223
# Node <spatial_scene_grammars_examples.table.grammar.PersonalPlate object at 0x7f162488bd30> getting tf tensor([[-0.2768, -0.9599, -0.0442,  0.0576],
#         [ 0.9606, -0.2752, -0.0383, -0.5366],
#         [ 0.0246, -0.0531,  0.9983,  0.8325],
#         [ 0.0000,  0.0000,  0.0000,  1.0000]])
# Added PlaceSetting_2124--(0)>PersonalPlate_2161
# Node <spatial_scene_grammars_examples.table.grammar.Teacup object at 0x7f162488b048> getting tf tensor([[-0.1324, -0.9911,  0.0105, -0.1901],
#         [ 0.9887, -0.1313,  0.0720, -0.0099],
#         [-0.0700,  0.0199,  0.9973,  0.8328],
#         [ 0.0000,  0.0000,  0.0000,  1.0000]])
# Added PlaceSetting_2124--(1)>Teacup_2224
# Node <spatial_scene_grammars_examples.table.grammar.Teapot object at 0x7f162488b278> getting tf tensor([[-0.9937,  0.0940, -0.0613,  0.0657],
#         [-0.0973, -0.9939,  0.0526,  0.2726],
#         [-0.0560,  0.0583,  0.9967,  0.8244],
#         [ 0.0000,  0.0000,  0.0000,  1.0000]])
# Added SharedTeapots_1767--(0)>Teapot_1873
# Node <spatial_scene_grammars_examples.table.grammar.ServingDish object at 0x7f162488b080> getting tf tensor([[-0.9238,  0.3829,  0.0059,  0.0865],
#         [-0.3822, -0.9227,  0.0501,  0.0173],
#         [ 0.0247,  0.0440,  0.9987,  0.8428],
#         [ 0.0000,  0.0000,  0.0000,  1.0000]])
# Added SharedDishes_1767--(0)>ServingDish_1873
# Node <spatial_scene_grammars_examples.table.grammar.SteamerBottom object at 0x7f162488b8d0> getting tf tensor([[ 0.9989,  0.0477,  0.0034, -0.2122],
#         [-0.0478,  0.9986,  0.0230,  0.1042],
#         [-0.0023, -0.0231,  0.9997,  0.8121],
#         [ 0.0000,  0.0000,  0.0000,  1.0000]])
# Added SharedSteamers_1767--(0)>SteamerBottom_3295
# Node <spatial_scene_grammars_examples.table.grammar.SteamerBottom object at 0x7f162488bc18> getting tf tensor([[ 8.4349e-01,  5.3568e-01, -3.9545e-02,  2.3123e-02],
#         [-5.3714e-01,  8.4126e-01, -6.1299e-02,  1.9116e-01],
#         [ 4.3083e-04,  7.2947e-02,  9.9734e-01,  8.3532e-01],
#         [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]])
# Added SharedSteamers_1767--(1)>SteamerBottom_3296
# Node <spatial_scene_grammars_examples.table.grammar.SteamerBottom object at 0x7f162488be80> getting tf tensor([[ 0.9726,  0.2309, -0.0279,  0.0291],
#         [-0.2306,  0.9730,  0.0142, -0.0620],
#         [ 0.0304, -0.0073,  0.9995,  0.8236],
#         [ 0.0000,  0.0000,  0.0000,  1.0000]])
# Added SharedSteamers_1767--(2)>SteamerBottom_3297
# Node <spatial_scene_grammars_examples.table.grammar.SteamerTop object at 0x7f16242785f8> getting tf tensor([[-0.7165,  0.6976, -0.0020, -0.2008],
#         [-0.6971, -0.7159,  0.0387,  0.1200],
#         [ 0.0256,  0.0291,  0.9992,  0.9190],
#         [ 0.0000,  0.0000,  0.0000,  1.0000]])
# Added SteamerBottom_3295--(1)>SteamerTop_3050
# Node <spatial_scene_grammars_examples.table.grammar.SteamerTop object at 0x7f16242782b0> getting tf tensor([[ 0.8329,  0.5524, -0.0341,  0.0124],
#         [-0.5532,  0.8288, -0.0838,  0.1797],
#         [-0.0180,  0.0887,  0.9959,  0.9360],
#         [ 0.0000,  0.0000,  0.0000,  1.0000]])
# Added SteamerBottom_3296--(1)>SteamerTop_3051
# Node <spatial_scene_grammars_examples.table.grammar.SteamerTop object at 0x7f15a1f88c18> getting tf tensor([[ 0.4591,  0.8882, -0.0158,  0.0303],
#         [-0.8879,  0.4594,  0.0257, -0.0565],
#         [ 0.0301,  0.0022,  0.9995,  0.9253],
#         [ 0.0000,  0.0000,  0.0000,  1.0000]])
# Added SteamerBottom_3297--(1)>SteamerTop_3052
# Building tree for sol 2...
# Node <spatial_scene_grammars_examples.table.grammar.Table object at 0x7f16248f2eb8> getting tf tensor([[1.0000, 0.0000, 0.0000, 0.0000],
#         [0.0000, 1.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 1.0000, 0.8000],
#         [0.0000, 0.0000, 0.0000, 1.0000]])
# Node <spatial_scene_grammars_examples.table.grammar.PlaceSettings object at 0x7f16242460f0> getting tf tensor([[1.0000, 0.0000, 0.0000, 0.0000],
#         [0.0000, 1.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 1.0000, 0.8250],
#         [0.0000, 0.0000, 0.0000, 1.0000]])
# Added Table_1793--(0)>PlaceSettings_1768
# Node <spatial_scene_grammars_examples.table.grammar.SharedStuff object at 0x7f1624246e10> getting tf tensor([[1.0000, 0.0000, 0.0000, 0.0000],
#         [0.0000, 1.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 1.0000, 0.8250],
#         [0.0000, 0.0000, 0.0000, 1.0000]])
# Added Table_1793--(1)>SharedStuff_1768
# Node <spatial_scene_grammars_examples.table.grammar.PlaceSetting object at 0x7f16242464e0> getting tf tensor([[ 1.0000,  0.0000,  0.0000, -0.5000],
#         [ 0.0000,  1.0000,  0.0000,  0.0000],
#         [ 0.0000,  0.0000,  1.0000,  0.8250],
#         [ 0.0000,  0.0000,  0.0000,  1.0000]])
# Added PlaceSettings_1768--(0)>PlaceSetting_2125
# Node <spatial_scene_grammars_examples.table.grammar.PlaceSetting object at 0x7f1624848390> getting tf tensor([[-1.0000e+00, -1.2246e-16,  0.0000e+00,  5.0000e-01],
#         [ 1.2246e-16, -1.0000e+00,  0.0000e+00,  0.0000e+00],
#         [ 0.0000e+00,  0.0000e+00,  1.0000e+00,  8.2500e-01],
#         [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]])
# Added PlaceSettings_1768--(1)>PlaceSetting_2126
# Node <spatial_scene_grammars_examples.table.grammar.PlaceSetting object at 0x7f15a43a30f0> getting tf tensor([[ 6.1232e-17,  1.0000e+00,  0.0000e+00,  0.0000e+00],
#         [-1.0000e+00,  6.1232e-17,  0.0000e+00,  5.0000e-01],
#         [ 0.0000e+00,  0.0000e+00,  1.0000e+00,  8.2500e-01],
#         [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]])
# Added PlaceSettings_1768--(2)>PlaceSetting_2127
# Node <spatial_scene_grammars_examples.table.grammar.PlaceSetting object at 0x7f15a43a3c18> getting tf tensor([[ 6.1232e-17, -1.0000e+00,  0.0000e+00,  0.0000e+00],
#         [ 1.0000e+00,  6.1232e-17,  0.0000e+00, -5.0000e-01],
#         [ 0.0000e+00,  0.0000e+00,  1.0000e+00,  8.2500e-01],
#         [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]])
# Added PlaceSettings_1768--(3)>PlaceSetting_2128
# Node <spatial_scene_grammars_examples.table.grammar.SharedTeapots object at 0x7f15a43a39e8> getting tf tensor([[1.0000, 0.0000, 0.0000, 0.0000],
#         [0.0000, 1.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 1.0000, 0.8250],
#         [0.0000, 0.0000, 0.0000, 1.0000]])
# Added SharedStuff_1768--(0)>SharedTeapots_1768
# Node <spatial_scene_grammars_examples.table.grammar.SharedDishes object at 0x7f15a43a35c0> getting tf tensor([[1.0000, 0.0000, 0.0000, 0.0000],
#         [0.0000, 1.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 1.0000, 0.8250],
#         [0.0000, 0.0000, 0.0000, 1.0000]])
# Added SharedStuff_1768--(1)>SharedDishes_1768
# Node <spatial_scene_grammars_examples.table.grammar.SharedSteamers object at 0x7f16242670b8> getting tf tensor([[1.0000, 0.0000, 0.0000, 0.0000],
#         [0.0000, 1.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 1.0000, 0.8250],
#         [0.0000, 0.0000, 0.0000, 1.0000]])
# Added SharedStuff_1768--(2)>SharedSteamers_1768
# Node <spatial_scene_grammars_examples.table.grammar.PersonalPlate object at 0x7f162488b588> getting tf tensor([[ 0.8506, -0.5258, -0.0012, -0.4718],
#         [ 0.5250,  0.8493,  0.0558, -0.0210],
#         [-0.0283, -0.0481,  0.9984,  0.7953],
#         [ 0.0000,  0.0000,  0.0000,  1.0000]])
# Added PlaceSetting_2125--(0)>PersonalPlate_2162
# Node <spatial_scene_grammars_examples.table.grammar.Teacup object at 0x7f162488b5f8> getting tf tensor([[-0.1324, -0.9911,  0.0105, -0.1901],
#         [ 0.9887, -0.1313,  0.0720, -0.0099],
#         [-0.0700,  0.0199,  0.9973,  0.8328],
#         [ 0.0000,  0.0000,  0.0000,  1.0000]])
# Added PlaceSetting_2125--(1)>Teacup_2225
# Node <spatial_scene_grammars_examples.table.grammar.Teacup object at 0x7f162488b240> getting tf tensor([[-0.4254, -0.9008,  0.0870,  0.2702],
#         [ 0.9042, -0.4272, -0.0019, -0.0168],
#         [ 0.0389,  0.0779,  0.9962,  0.8213],
#         [ 0.0000,  0.0000,  0.0000,  1.0000]])
# Added PlaceSetting_2126--(1)>Teacup_2226
# Node <spatial_scene_grammars_examples.table.grammar.PersonalPlate object at 0x7f162488b0f0> getting tf tensor([[-0.9498, -0.3014, -0.0844,  0.0171],
#         [ 0.3013, -0.9534,  0.0137,  0.4378],
#         [-0.0846, -0.0124,  0.9963,  0.8278],
#         [ 0.0000,  0.0000,  0.0000,  1.0000]])
# Added PlaceSetting_2127--(0)>PersonalPlate_2163
# Node <spatial_scene_grammars_examples.table.grammar.Teacup object at 0x7f162488bd68> getting tf tensor([[-0.9961,  0.0246, -0.0848, -0.0851],
#         [-0.0221, -0.9993, -0.0294, -0.2046],
#         [-0.0855, -0.0274,  0.9960,  0.8351],
#         [ 0.0000,  0.0000,  0.0000,  1.0000]])
# Added PlaceSetting_2127--(1)>Teacup_2227
# Node <spatial_scene_grammars_examples.table.grammar.PersonalPlate object at 0x7f162488bd30> getting tf tensor([[-0.2768, -0.9599, -0.0442,  0.0576],
#         [ 0.9606, -0.2752, -0.0383, -0.5366],
#         [ 0.0246, -0.0531,  0.9983,  0.8325],
#         [ 0.0000,  0.0000,  0.0000,  1.0000]])
# Added PlaceSetting_2128--(0)>PersonalPlate_2164
# Node <spatial_scene_grammars_examples.table.grammar.Teacup object at 0x7f162488b048> getting tf tensor([[-0.7329, -0.6803,  0.0084, -0.0123],
#         [ 0.6802, -0.7325,  0.0267,  0.2589],
#         [-0.0120,  0.0252,  0.9996,  0.8176],
#         [ 0.0000,  0.0000,  0.0000,  1.0000]])
# Added PlaceSetting_2128--(1)>Teacup_2228
# Node <spatial_scene_grammars_examples.table.grammar.Teapot object at 0x7f162488b278> getting tf tensor([[-0.9937,  0.0940, -0.0613,  0.0657],
#         [-0.0973, -0.9939,  0.0526,  0.2726],
#         [-0.0560,  0.0583,  0.9967,  0.8244],
#         [ 0.0000,  0.0000,  0.0000,  1.0000]])
# Added SharedTeapots_1768--(0)>Teapot_1874
# Node <spatial_scene_grammars_examples.table.grammar.ServingDish object at 0x7f162488b080> getting tf tensor([[-0.9238,  0.3829,  0.0059,  0.0865],
#         [-0.3822, -0.9227,  0.0501,  0.0173],
#         [ 0.0247,  0.0440,  0.9987,  0.8428],
#         [ 0.0000,  0.0000,  0.0000,  1.0000]])
# Added SharedDishes_1768--(0)>ServingDish_1874
# Node <spatial_scene_grammars_examples.table.grammar.SteamerBottom object at 0x7f162488b8d0> getting tf tensor([[ 0.9989,  0.0477,  0.0034, -0.2122],
#         [-0.0478,  0.9986,  0.0230,  0.1042],
#         [-0.0023, -0.0231,  0.9997,  0.8121],
#         [ 0.0000,  0.0000,  0.0000,  1.0000]])
# Added SharedSteamers_1768--(0)>SteamerBottom_3298
# Node <spatial_scene_grammars_examples.table.grammar.SteamerBottom object at 0x7f162488bc18> getting tf tensor([[ 8.4349e-01,  5.3568e-01, -3.9545e-02,  2.3123e-02],
#         [-5.3714e-01,  8.4126e-01, -6.1299e-02,  1.9116e-01],
#         [ 4.3083e-04,  7.2947e-02,  9.9734e-01,  8.3532e-01],
#         [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]])
# Added SharedSteamers_1768--(1)>SteamerBottom_3299
# Node <spatial_scene_grammars_examples.table.grammar.SteamerBottom object at 0x7f162488be80> getting tf tensor([[ 0.9726,  0.2309, -0.0279,  0.0291],
#         [-0.2306,  0.9730,  0.0142, -0.0620],
#         [ 0.0304, -0.0073,  0.9995,  0.8236],
#         [ 0.0000,  0.0000,  0.0000,  1.0000]])
# Added SharedSteamers_1768--(2)>SteamerBottom_3300
# Node <spatial_scene_grammars_examples.table.grammar.SteamerTop object at 0x7f16242785f8> getting tf tensor([[-0.7165,  0.6976, -0.0020, -0.2008],
#         [-0.6971, -0.7159,  0.0387,  0.1200],
#         [ 0.0256,  0.0291,  0.9992,  0.9190],
#         [ 0.0000,  0.0000,  0.0000,  1.0000]])
# Added SteamerBottom_3298--(1)>SteamerTop_3053
# Node <spatial_scene_grammars_examples.table.grammar.SteamerTop object at 0x7f16242782b0> getting tf tensor([[ 0.8329,  0.5524, -0.0341,  0.0124],
#         [-0.5532,  0.8288, -0.0838,  0.1797],
#         [-0.0180,  0.0887,  0.9959,  0.9360],
#         [ 0.0000,  0.0000,  0.0000,  1.0000]])
# Added SteamerBottom_3299--(1)>SteamerTop_3054
# Node <spatial_scene_grammars_examples.table.grammar.SteamerTop object at 0x7f15a1f88c18> getting tf tensor([[ 0.4591,  0.8882, -0.0158,  0.0303],
#         [-0.8879,  0.4594,  0.0257, -0.0565],
#         [ 0.0301,  0.0022,  0.9995,  0.9253],
#         [ 0.0000,  0.0000,  0.0000,  1.0000]])
# Added SteamerBottom_3300--(1)>SteamerTop_3055
# Building tree for sol 3...
# Node <spatial_scene_grammars_examples.table.grammar.Table object at 0x7f16248f2eb8> getting tf tensor([[1.0000, 0.0000, 0.0000, 0.0000],
#         [0.0000, 1.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 1.0000, 0.8000],
#         [0.0000, 0.0000, 0.0000, 1.0000]])
# Node <spatial_scene_grammars_examples.table.grammar.PlaceSettings object at 0x7f16242460f0> getting tf tensor([[1.0000, 0.0000, 0.0000, 0.0000],
#         [0.0000, 1.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 1.0000, 0.8250],
#         [0.0000, 0.0000, 0.0000, 1.0000]])
# Added Table_1794--(0)>PlaceSettings_1769
# Node <spatial_scene_grammars_examples.table.grammar.SharedStuff object at 0x7f1624246e10> getting tf tensor([[1.0000, 0.0000, 0.0000, 0.0000],
#         [0.0000, 1.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 1.0000, 0.8250],
#         [0.0000, 0.0000, 0.0000, 1.0000]])
# Added Table_1794--(1)>SharedStuff_1769
# Node <spatial_scene_grammars_examples.table.grammar.PlaceSetting object at 0x7f16242464e0> getting tf tensor([[ 1.0000,  0.0000,  0.0000, -0.5000],
#         [ 0.0000,  1.0000,  0.0000,  0.0000],
#         [ 0.0000,  0.0000,  1.0000,  0.8250],
#         [ 0.0000,  0.0000,  0.0000,  1.0000]])
# Added PlaceSettings_1769--(0)>PlaceSetting_2129
# Node <spatial_scene_grammars_examples.table.grammar.PlaceSetting object at 0x7f1624848390> getting tf tensor([[-1.0000e+00, -1.2246e-16,  0.0000e+00,  5.0000e-01],
#         [ 1.2246e-16, -1.0000e+00,  0.0000e+00,  0.0000e+00],
#         [ 0.0000e+00,  0.0000e+00,  1.0000e+00,  8.2500e-01],
#         [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]])
# Added PlaceSettings_1769--(1)>PlaceSetting_2130
# Node <spatial_scene_grammars_examples.table.grammar.PlaceSetting object at 0x7f15a43a30f0> getting tf tensor([[ 6.1232e-17,  1.0000e+00,  0.0000e+00,  0.0000e+00],
#         [-1.0000e+00,  6.1232e-17,  0.0000e+00,  5.0000e-01],
#         [ 0.0000e+00,  0.0000e+00,  1.0000e+00,  8.2500e-01],
#         [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]])
# Added PlaceSettings_1769--(2)>PlaceSetting_2131
# Node <spatial_scene_grammars_examples.table.grammar.PlaceSetting object at 0x7f15a43a3c18> getting tf tensor([[ 6.1232e-17, -1.0000e+00,  0.0000e+00,  0.0000e+00],
#         [ 1.0000e+00,  6.1232e-17,  0.0000e+00, -5.0000e-01],
#         [ 0.0000e+00,  0.0000e+00,  1.0000e+00,  8.2500e-01],
#         [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]])
# Added PlaceSettings_1769--(3)>PlaceSetting_2132
# Node <spatial_scene_grammars_examples.table.grammar.SharedTeapots object at 0x7f15a43a39e8> getting tf tensor([[1.0000, 0.0000, 0.0000, 0.0000],
#         [0.0000, 1.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 1.0000, 0.8250],
#         [0.0000, 0.0000, 0.0000, 1.0000]])
# Added SharedStuff_1769--(0)>SharedTeapots_1769
# Node <spatial_scene_grammars_examples.table.grammar.SharedDishes object at 0x7f15a43a35c0> getting tf tensor([[1.0000, 0.0000, 0.0000, 0.0000],
#         [0.0000, 1.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 1.0000, 0.8250],
#         [0.0000, 0.0000, 0.0000, 1.0000]])
# Added SharedStuff_1769--(1)>SharedDishes_1769
# Node <spatial_scene_grammars_examples.table.grammar.SharedSteamers object at 0x7f16242670b8> getting tf tensor([[1.0000, 0.0000, 0.0000, 0.0000],
#         [0.0000, 1.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 1.0000, 0.8250],
#         [0.0000, 0.0000, 0.0000, 1.0000]])
# Added SharedStuff_1769--(2)>SharedSteamers_1769
# Node <spatial_scene_grammars_examples.table.grammar.PersonalPlate object at 0x7f162488b588> getting tf tensor([[ 0.8506, -0.5258, -0.0012, -0.4718],
#         [ 0.5250,  0.8493,  0.0558, -0.0210],
#         [-0.0283, -0.0481,  0.9984,  0.7953],
#         [ 0.0000,  0.0000,  0.0000,  1.0000]])
# Added PlaceSetting_2129--(0)>PersonalPlate_2165
# Node <spatial_scene_grammars_examples.table.grammar.Teacup object at 0x7f162488b5f8> getting tf tensor([[-0.7329, -0.6803,  0.0084, -0.0123],
#         [ 0.6802, -0.7325,  0.0267,  0.2589],
#         [-0.0120,  0.0252,  0.9996,  0.8176],
#         [ 0.0000,  0.0000,  0.0000,  1.0000]])
# Added PlaceSetting_2129--(1)>Teacup_2229
# Node <spatial_scene_grammars_examples.table.grammar.Teacup object at 0x7f162488b240> getting tf tensor([[-0.4254, -0.9008,  0.0870,  0.2702],
#         [ 0.9042, -0.4272, -0.0019, -0.0168],
#         [ 0.0389,  0.0779,  0.9962,  0.8213],
#         [ 0.0000,  0.0000,  0.0000,  1.0000]])
# Added PlaceSetting_2130--(1)>Teacup_2230
# Node <spatial_scene_grammars_examples.table.grammar.PersonalPlate object at 0x7f162488b0f0> getting tf tensor([[-0.9498, -0.3014, -0.0844,  0.0171],
#         [ 0.3013, -0.9534,  0.0137,  0.4378],
#         [-0.0846, -0.0124,  0.9963,  0.8278],
#         [ 0.0000,  0.0000,  0.0000,  1.0000]])
# Added PlaceSetting_2131--(0)>PersonalPlate_2166
# Node <spatial_scene_grammars_examples.table.grammar.Teacup object at 0x7f162488bd68> getting tf tensor([[-0.1324, -0.9911,  0.0105, -0.1901],
#         [ 0.9887, -0.1313,  0.0720, -0.0099],
#         [-0.0700,  0.0199,  0.9973,  0.8328],
#         [ 0.0000,  0.0000,  0.0000,  1.0000]])
# Added PlaceSetting_2131--(1)>Teacup_2231
# Node <spatial_scene_grammars_examples.table.grammar.PersonalPlate object at 0x7f162488bd30> getting tf tensor([[-0.2768, -0.9599, -0.0442,  0.0576],
#         [ 0.9606, -0.2752, -0.0383, -0.5366],
#         [ 0.0246, -0.0531,  0.9983,  0.8325],
#         [ 0.0000,  0.0000,  0.0000,  1.0000]])
# Added PlaceSetting_2132--(0)>PersonalPlate_2167
# Node <spatial_scene_grammars_examples.table.grammar.Teacup object at 0x7f162488b048> getting tf tensor([[-0.9961,  0.0246, -0.0848, -0.0851],
#         [-0.0221, -0.9993, -0.0294, -0.2046],
#         [-0.0855, -0.0274,  0.9960,  0.8351],
#         [ 0.0000,  0.0000,  0.0000,  1.0000]])
# Added PlaceSetting_2132--(1)>Teacup_2232
# Node <spatial_scene_grammars_examples.table.grammar.Teapot object at 0x7f162488b278> getting tf tensor([[-0.9937,  0.0940, -0.0613,  0.0657],
#         [-0.0973, -0.9939,  0.0526,  0.2726],
#         [-0.0560,  0.0583,  0.9967,  0.8244],
#         [ 0.0000,  0.0000,  0.0000,  1.0000]])
# Added SharedTeapots_1769--(0)>Teapot_1875
# Node <spatial_scene_grammars_examples.table.grammar.ServingDish object at 0x7f162488b080> getting tf tensor([[-0.9238,  0.3829,  0.0059,  0.0865],
#         [-0.3822, -0.9227,  0.0501,  0.0173],
#         [ 0.0247,  0.0440,  0.9987,  0.8428],
#         [ 0.0000,  0.0000,  0.0000,  1.0000]])
# Added SharedDishes_1769--(0)>ServingDish_1875
# Node <spatial_scene_grammars_examples.table.grammar.SteamerBottom object at 0x7f162488b8d0> getting tf tensor([[ 0.9989,  0.0477,  0.0034, -0.2122],
#         [-0.0478,  0.9986,  0.0230,  0.1042],
#         [-0.0023, -0.0231,  0.9997,  0.8121],
#         [ 0.0000,  0.0000,  0.0000,  1.0000]])
# Added SharedSteamers_1769--(0)>SteamerBottom_3301
# Node <spatial_scene_grammars_examples.table.grammar.SteamerBottom object at 0x7f162488bc18> getting tf tensor([[ 8.4349e-01,  5.3568e-01, -3.9545e-02,  2.3123e-02],
#         [-5.3714e-01,  8.4126e-01, -6.1299e-02,  1.9116e-01],
#         [ 4.3083e-04,  7.2947e-02,  9.9734e-01,  8.3532e-01],
#         [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]])
# Added SharedSteamers_1769--(1)>SteamerBottom_3302
# Node <spatial_scene_grammars_examples.table.grammar.SteamerBottom object at 0x7f162488be80> getting tf tensor([[ 0.9726,  0.2309, -0.0279,  0.0291],
#         [-0.2306,  0.9730,  0.0142, -0.0620],
#         [ 0.0304, -0.0073,  0.9995,  0.8236],
#         [ 0.0000,  0.0000,  0.0000,  1.0000]])
# Added SharedSteamers_1769--(2)>SteamerBottom_3303
# Node <spatial_scene_grammars_examples.table.grammar.SteamerTop object at 0x7f16242785f8> getting tf tensor([[-0.7165,  0.6976, -0.0020, -0.2008],
#         [-0.6971, -0.7159,  0.0387,  0.1200],
#         [ 0.0256,  0.0291,  0.9992,  0.9190],
#         [ 0.0000,  0.0000,  0.0000,  1.0000]])
# Added SteamerBottom_3301--(1)>SteamerTop_3056
# Node <spatial_scene_grammars_examples.table.grammar.SteamerTop object at 0x7f16242782b0> getting tf tensor([[ 0.8329,  0.5524, -0.0341,  0.0124],
#         [-0.5532,  0.8288, -0.0838,  0.1797],
#         [-0.0180,  0.0887,  0.9959,  0.9360],
#         [ 0.0000,  0.0000,  0.0000,  1.0000]])
# Added SteamerBottom_3302--(1)>SteamerTop_3057
# Node <spatial_scene_grammars_examples.table.grammar.SteamerTop object at 0x7f15a1f88c18> getting tf tensor([[ 0.4591,  0.8882, -0.0158,  0.0303],
#         [-0.8879,  0.4594,  0.0257, -0.0565],
#         [ 0.0301,  0.0022,  0.9995,  0.9253],
#         [ 0.0000,  0.0000,  0.0000,  1.0000]])
# Added SteamerBottom_3303--(1)>SteamerTop_3058
# SOL #0: SCORE -82.786124
